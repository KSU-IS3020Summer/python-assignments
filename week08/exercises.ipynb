# %% [markdown]
# # Week 8: File I/O & Error Handling
#
# **Topics:** open, read, write, try/except, with statement
# **Note:** Some exercises create/read files. Make sure you run them in order.

# %% [markdown]
# ---
# ### Exercise 1
# Write a function `write_students(filename, students)` that writes a list of student dicts to a file.
#
# Format: one line per student as `name,score`

# %%
# Exercise 1
def write_students(filename, students):
    pass

# Test
students = [
    {"name": "Alice", "score": 90},
    {"name": "Bob", "score": 78},
    {"name": "Charlie", "score": 85}
]
write_students("students.txt", students)
print("File written! Check students.txt")

# %% [markdown]
# ### Exercise 2
# Write a function `read_students(filename)` that reads the file from Exercise 1 and returns a list of dicts.
#
# Handle the case where the file doesn't exist (return empty list).

# %%
# Exercise 2
def read_students(filename):
    pass

# Test
data = read_students("students.txt")
print(data)
# Should print: [{"name": "Alice", "score": 90}, ...]

# %% [markdown]
# ### Exercise 3
# Write a function `count_lines(filename)` that returns the number of non-empty lines.
#
# If the file doesn't exist, return -1 (use try/except).

# %%
# Exercise 3
def count_lines(filename):
    pass

# Test
print(count_lines("students.txt"))      # 3
print(count_lines("nonexistent.txt"))    # -1

# %% [markdown]
# ### Exercise 4
# Write a function `safe_divide(a, b)` that handles errors:
# - If b is 0: return `"Cannot divide by zero"`
# - If a or b is not a number: return `"Invalid input"`
# - Otherwise: return the result as a float
#
# Use try/except.

# %%
# Exercise 4
def safe_divide(a, b):
    pass

# Test
print(safe_divide(10, 3))      # 3.333...
print(safe_divide(10, 0))      # Cannot divide by zero
print(safe_divide("abc", 2))   # Invalid input

# %% [markdown]
# ### Exercise 5
# Write a function `parse_csv(text)` that takes a CSV-formatted **string** and returns a list of dictionaries.
#
# First line is the header row.

# %%
# Exercise 5
def parse_csv(text):
    pass

# Test
csv_text = "name,age,city\nAlice,30,NYC\nBob,25,LA\nCharlie,35,Chicago"
result = parse_csv(csv_text)
print(result)
# [{"name": "Alice", "age": "30", "city": "NYC"}, ...]

# %% [markdown]
# ### Exercise 6
# Write a function `log_message(filename, message, level="INFO")` that appends a log entry.
#
# Format: `[LEVEL] message`
#
# Create the file if it doesn't exist.

# %%
# Exercise 6
def log_message(filename, message, level="INFO"):
    pass

# Test
log_message("app.log", "Server started")
log_message("app.log", "Connection failed", "ERROR")
log_message("app.log", "Retrying...", "WARNING")
print(open("app.log").read())

# %% [markdown]
# ### Exercise 7
# Write a function `word_count_file(filename)` that reads a file and returns a dictionary of word counts.
#
# Case-insensitive. Strip punctuation (.,!?;:) from words.

# %%
# Exercise 7
def word_count_file(filename):
    pass

# Test — first create a test file
with open("sample.txt", "w") as f:
    f.write("Hello, hello! World. Python is great.\nPython is fun. Hello world!")

result = word_count_file("sample.txt")
print(result)
# {"hello": 3, "world": 2, "python": 2, "is": 2, "great": 1, "fun": 1}

# %% [markdown]
# ### Exercise 8
# Write a function `grade_report(input_file, output_file)` that:
# 1. Reads student data from input_file (name,score format)
# 2. Writes a report to output_file with:
#    - Each student: `name: score (grade letter)`
#    - Last line: `Class Average: X.X`
#
# Use functions from previous exercises!

# %%
# Exercise 8
def grade_report(input_file, output_file):
    pass

# Test
grade_report("students.txt", "report.txt")
print(open("report.txt").read())

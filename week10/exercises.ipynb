# %% [markdown]
# # Week 10: Final Project — Student Management System
#
# ## Overview
# Build a complete program that combines everything you've learned this semester.
#
# ## Requirements
# Your system must include:
# 1. **Classes** (Week 9) — Student class and Course class
# 2. **File I/O** (Week 8) — Save and load data
# 3. **Functions** (Week 7) — Organized, reusable code
# 4. **Data Structures** (Weeks 4-6) — Lists and dictionaries
# 5. **Control Flow** (Weeks 2, 5) — Loops and conditionals
#
# ## Features to Implement
# 1. Add a new student (name, ID)
# 2. Add grades to a student
# 3. View all students and their averages
# 4. Find the top student
# 5. Search for a student by name
# 6. Save all data to a file
# 7. Load data from a file
#
# ## Grading
# - Code runs without errors: 30%
# - All 7 features work: 40%
# - Clean code (functions, variable names, comments): 15%
# - Uses classes properly: 15%
#
# ## Instructions
# Build your entire program in the cells below. Organize with comments and functions.

# %% [markdown]
# ---
# ### Step 1: Define your Student class

# %%
# Define your Student class here

# %% [markdown]
# ### Step 2: Define your Course class (manages a collection of students)

# %%
# Define your Course class here

# %% [markdown]
# ### Step 3: File I/O functions (save and load)

# %%
# Write save_data() and load_data() functions here

# %% [markdown]
# ### Step 4: Menu and main program logic

# %%
# Write your menu-driven program here
# Use a while loop with options 1-7

# %% [markdown]
# ### Step 5: Test your program

# %%
# Test all 7 features here
# You can call functions directly instead of using input()

# %% [markdown]
# # Week 3: Strings & String Methods
#
# **Topics:** slicing, f-strings, .upper(), .split(), .replace(), .find()
# **Instructions:** Write your code in each cell below.

# %% [markdown]
# ---
# ### Exercise 1
# Given the text below, count the number of vowels (a, e, i, o, u). Case-insensitive.
#
# Print: `"Vowel count: X"`

# %%
# Exercise 1: Count vowels
text = "Learning Python is an Amazing Journey"
count = 0

# %% [markdown]
# ### Exercise 2
# Given a sentence, reverse the order of words (not the letters).
#
# Example: `"Hello World"` → `"World Hello"`

# %%
# Exercise 2: Reverse word order
sentence = "I love Python programming"

# %% [markdown]
# ### Exercise 3
# Check if the given text is a palindrome (reads the same forwards and backwards).
# Ignore case and spaces.
#
# Test with: `"racecar"`, `"Race Car"`, `"hello"`

# %%
# Exercise 3: Palindrome checker
text = "Race Car"

# %% [markdown]
# ### Exercise 4
# Given a sentence, replace all occurrences of a word with asterisks of the same length.
# Case-insensitive replacement.
#
# Example: `"I love cats and Cats love me"` with word `"cats"` → `"I love **** and **** love me"`

# %%
# Exercise 4: Word censor
sentence = "I love cats and Cats love me"
censor_word = "cats"

# %% [markdown]
# ### Exercise 5
# Convert text to title case (capitalize first letter of each word).
# **Do NOT use the built-in `.title()` method.** Use a loop.
#
# Example: `"hello world"` → `"Hello World"`

# %%
# Exercise 5: Manual title case
text = "python is fun to learn"

# %% [markdown]
# ### Exercise 6
# Extract all email addresses from the text below.
# An email contains `@` — split by spaces and check each word.
#
# Print each email found.

# %%
# Exercise 6: Extract emails
text = "Contact john@gmail.com for info or jane@yahoo.com for support. Visit our website."

# %% [markdown]
# ### Exercise 7
# Convert a word to Pig Latin:
# - If it starts with a vowel: add `"yay"` → `"apple"` → `"appleyay"`
# - If it starts with a consonant: move first letter to end, add `"ay"` → `"hello"` → `"ellohay"`
#
# Test with: `"apple"`, `"hello"`, `"python"`

# %%
# Exercise 7: Pig Latin
word = "hello"

# %% [markdown]
# ### Exercise 8
# Compress a string by counting consecutive repeated characters.
#
# Example: `"aaabbbcc"` → `"a3b3c2"`
# Example: `"abcd"` → `"a1b1c1d1"`

# %%
# Exercise 8: String compression
text = "aaabbbcc"

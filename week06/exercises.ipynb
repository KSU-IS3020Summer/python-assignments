# %% [markdown]
# # Week 6: Dictionaries & Sets
#
# **Topics:** key-value pairs, .keys(), .values(), .items(), set operations
# **Instructions:** Write your code in each cell below.

# %% [markdown]
# ---
# ### Exercise 1
# Count the frequency of each word in the text (case-insensitive).
#
# Print each word and its count, sorted by count (highest first).

# %%
# Exercise 1: Word frequency
text = "the cat sat on the mat and the cat ate the food"

# %% [markdown]
# ### Exercise 2
# Merge two dictionaries. If a key exists in both, add the values together.
#
# Print the merged result.

# %%
# Exercise 2: Merge dictionaries
dict1 = {"a": 1, "b": 2, "c": 3}
dict2 = {"b": 4, "c": 5, "d": 6}

# %% [markdown]
# ### Exercise 3
# Invert a dictionary — swap keys and values.
# If multiple keys have the same value, store them as a list.
#
# Example: `{"a": 1, "b": 2, "c": 1}` → `{1: ["a", "c"], 2: ["b"]}`

# %%
# Exercise 3: Invert dictionary
original = {"apple": "fruit", "carrot": "vegetable", "banana": "fruit", "broccoli": "vegetable", "cherry": "fruit"}

# %% [markdown]
# ### Exercise 4
# Group a list of words by their length.
#
# Example: `["hi", "hey", "hello", "go"]` → `{2: ["hi", "go"], 3: ["hey"], 5: ["hello"]}`

# %%
# Exercise 4: Group by length
words = ["cat", "dog", "elephant", "ant", "tiger", "bee", "dolphin", "ox"]

# %% [markdown]
# ### Exercise 5
# Create a phone book from a list of entries. If a person has multiple numbers, store as a list.
#
# Print the phone book.

# %%
# Exercise 5: Phone book
entries = [
    ("Alice", "555-0101"),
    ("Bob", "555-0202"),
    ("Alice", "555-0303"),
    ("Charlie", "555-0404"),
    ("Bob", "555-0505")
]

# %% [markdown]
# ### Exercise 6
# Given student scores, rank them (highest = rank 1).
#
# Print each student with their rank.

# %%
# Exercise 6: Student rankings
scores = {"Alice": 90, "Bob": 85, "Charlie": 95, "Diana": 78, "Eve": 92}

# %% [markdown]
# ### Exercise 7
# Implement set operations using loops (not the `set` type):
# - Union: all unique elements from both lists
# - Intersection: elements in both
# - Difference: elements in list1 but not list2
#
# Print each result sorted.

# %%
# Exercise 7: Manual set operations
list1 = [1, 2, 3, 4, 5]
list2 = [3, 4, 5, 6, 7]

# %% [markdown]
# ### Exercise 8
# Find the n most common elements in a list.
# Print each element with its count.
#
# Find the top 3 most common from the list below.

# %%
# Exercise 8: Most common elements
items = ["apple", "banana", "apple", "cherry", "banana", "apple", "date", "banana", "cherry", "apple"]
top_n = 3

# %% [markdown]
# # Week 5: For Loops & While Loops
#
# **Topics:** range(), break, continue, nested loops
# **Instructions:** Write your code in each cell below.

# %% [markdown]
# ---
# ### Exercise 1
# Print the multiplication table for a given number (1 through 10).
#
# Format: `"5 x 1 = 5"`, `"5 x 2 = 10"`, etc.

# %%
# Exercise 1: Multiplication table
number = 7

# %% [markdown]
# ### Exercise 2
# Find all prime numbers up to 50. A prime number is only divisible by 1 and itself.
#
# Print them as a list.

# %%
# Exercise 2: Prime numbers up to 50

# %% [markdown]
# ### Exercise 3
# Generate the first 15 Fibonacci numbers.
#
# Sequence: 0, 1, 1, 2, 3, 5, 8, 13, ...

# %%
# Exercise 3: Fibonacci sequence

# %% [markdown]
# ### Exercise 4
# Collatz conjecture: Start with any number.
# - If even: divide by 2
# - If odd: multiply by 3, add 1
# - Repeat until you reach 1
#
# Print each step and count how many steps it takes.
#
# Test with n = 27.

# %%
# Exercise 4: Collatz conjecture
n = 27

# %% [markdown]
# ### Exercise 5
# Print these patterns using nested loops:
# ```
# *
# **
# ***
# ****
# *****
# ```
# Then print the reverse:
# ```
# *****
# ****
# ***
# **
# *
# ```

# %%
# Exercise 5: Star patterns
rows = 5

# %% [markdown]
# ### Exercise 6
# Calculate the sum of all digits in a number. Handle negative numbers too.
#
# Example: 12345 → 1+2+3+4+5 = 15
# Example: -456 → 4+5+6 = 15
#
# Use a while loop, not string conversion.

# %%
# Exercise 6: Sum of digits
number = 12345

# %% [markdown]
# ### Exercise 7
# Simulate a number guessing game. The secret number is 42.
# Given a list of guesses, print `"too low"`, `"too high"`, or `"correct!"` for each.
# Stop after the correct guess.
#
# Guesses: `[20, 50, 40, 45, 42, 30]`

# %%
# Exercise 7: Number guessing game
secret = 42
guesses = [20, 50, 40, 45, 42, 30]

# %% [markdown]
# ### Exercise 8
# Find common elements between two lists using loops (not sets).
# Print the sorted list of unique common elements.
#
# Example: `[1,2,3,4,5]` and `[3,4,5,6,7]` → `[3, 4, 5]`

# %%
# Exercise 8: Common elements
list1 = [1, 2, 3, 4, 5, 6]
list2 = [4, 5, 6, 7, 8, 9]
